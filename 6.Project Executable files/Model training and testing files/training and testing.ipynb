# %% [markdown]
# ## **Data Collection**

# %%
#importing the dependencies
import pandas as pd
import numpy as np

# %%
#import dataset to the pandas dataframe
data=pd.read_csv('/content/garments_worker_productivity.csv')

# %% [markdown]
# # **Visualizing And Analyzing The Data**

# %% [markdown]
# ### **Read The Dataset**

# %%
#printing first 5 rows
data.head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 1                   0            8.0             0.886500
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382

# %%
#printing last 5 rows
data.tail()
# Out:
#            date   quarter department        day  team  targeted_productivity  \
# 1192  3/11/2015  Quarter2  finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2  finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2  finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2  finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2  finishing  Wednesday     6                   0.70
#
#       smv  wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 1192  2.9  NaN        960          0        0.0         0                   0
# 1193  3.9  NaN        960          0        0.0         0                   0
# 1194  3.9  NaN        960          0        0.0         0                   0
# 1195  2.9  NaN       1800          0        0.0         0                   0
# 1196  2.9  NaN        720          0        0.0         0                   0
#
#       no_of_workers  actual_productivity
# 1192            8.0             0.628333
# 1193            8.0             0.625625
# 1194            8.0             0.625625
# 1195           15.0             0.505889
# 1196            6.0             0.394722

# %%
#checking the rows and columns of dataset
data.shape
# Out:
# (1197, 15)

# %%
#checking some info about the datset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
#  14  actual_productivity    1197 non-null   float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB

# %% [markdown]
# ### **Importing The Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Univariate Analysis**

# %%
sns.distplot(data.smv)
# Out:
# <ipython-input-528-28de155260c7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.smv)
# <Axes: xlabel='smv', ylabel='Density'>

# %%
sns.distplot(data.targeted_productivity)
# Out:
# <ipython-input-529-77d0c7508f1b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.targeted_productivity)
# <Axes: xlabel='targeted_productivity', ylabel='Density'>

# %%
sns.distplot(data.over_time)
# Out:
# <ipython-input-530-d3aeff6f0869>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.over_time)
# <Axes: xlabel='over_time', ylabel='Density'>

# %%
sns.distplot(data.no_of_workers)
# Out:
# <ipython-input-531-9cf1046a1c4f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.no_of_workers)
# <Axes: xlabel='no_of_workers', ylabel='Density'>

# %%
sns.displot(data.no_of_style_change)

# %% [markdown]
# ### **Bivariate Analysis**

# %%
# Line plot to check actual and targeted productivity
plt.figure(figsize=(10,6))

sns.lineplot(x='date', y='actual_productivity', data=data, ci= None, color='orange' )
sns.lineplot(x='date', y='targeted_productivity', data=data, ci= None, color='darkblue')

plt.legend(labels=['actual_productivity','targeted_productivity'])
plt.ylabel("productivity")
plt.title("Comparison between Actual and Targeted Productivity over time")
plt.show()
# Out:
# <ipython-input-533-4ded7db4c00a>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='date', y='actual_productivity', data=data, ci= None, color='orange' )
# <ipython-input-533-4ded7db4c00a>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='date', y='targeted_productivity', data=data, ci= None, color='darkblue')

# %%
# Line plot to check actual productivity vs department
plt.figure(figsize=(10,8))
sns.lineplot(x='date', y='actual_productivity', hue = 'department',style= 'department', data=data, ci= None, markers=True, dashes=False)
# sns.lineplot(x='date', y='targeted_productivity', data=df, ci= None)
plt.title("Actual Productivity per Department over time")
plt.show()
# Out:
# <ipython-input-534-59bdf6ab8eef>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='date', y='actual_productivity', hue = 'department',style= 'department', data=data, ci= None, markers=True, dashes=False)

# %%
#Average actual productivity by day of week, department, quarter of the month, and team.

category = ["quarter", "department", "day", "team", "no_of_style_change"]

fig,axes = plt.subplots(nrows=2, ncols=2,figsize=(15,8))

for i, ax in enumerate(axes.ravel()):

    data.groupby([category[i]])['actual_productivity'].mean().nsmallest(data[category[i]].nunique()).plot.bar(ax=ax, color='purple')

    ax.set_title(f" Average actual productivity by {title(category[i])}")
    ax.set_xlabel(title(category[i]))
    ax.set_ylabel("average actual productivity")

fig.tight_layout()
plt.subplots_adjust(top=1.5)
plt.show()

# %%
#Average Productivity of each team
sns.catplot(data=data,x='department',y='actual_productivity',hue='team', ci=None, kind = 'bar')
plt.title("Average actual productivity per department")
plt.show()
# Out:
# <ipython-input-536-a0c42d07fa64>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(data=data,x='department',y='actual_productivity',hue='team', ci=None, kind = 'bar')

# %%
#Department and team with more style changes
sns.barplot(x='department', y='no_of_style_change',hue ='team' ,data=data, ci= None, estimator=sum)
plt.title("Department and team with more style changes")
plt.show()
# Out:
# <ipython-input-537-cfae1a2861ef>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='department', y='no_of_style_change',hue ='team' ,data=data, ci= None, estimator=sum)

# %%
#Idle men by department
sns.barplot(x='department', y='idle_men',hue ='team' ,data=data, ci= None, estimator=sum)
plt.title("Idle men by department")
plt.show()
# Out:
# <ipython-input-538-5c189e0d8dcd>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='department', y='idle_men',hue ='team' ,data=data, ci= None, estimator=sum)

# %%
#Average Productivity of each team
sns.catplot(data=data,x='department',y='actual_productivity',hue='team', ci=None, kind = 'bar')
plt.title("Average actual productivity per department")
plt.show()
# Out:
# <ipython-input-539-a0c42d07fa64>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(data=data,x='department',y='actual_productivity',hue='team', ci=None, kind = 'bar')

# %%
sns.pairplot(data)

# %% [markdown]
# ### **Correlation Analysis**

# %% [markdown]
# Correlation analysis is in Data Preprocessing step.Because,without handling date and department columns and without encoding the data it not possible to analyse the correlation .
#    Therefore,Corelation analysis is included in Data Preprocessing Step

# %% [markdown]
# ### **Descriptive Analysis**

# %%
data.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# 25%     1440.000000     0.000000     0.000000     0.000000
# 50%     3960.000000     0.000000     0.000000     0.000000
# 75%     6960.000000    50.000000     0.000000     0.000000
# max    25920.000000  3600.000000   300.000000    45.000000
#
#        no_of_style_change  no_of_workers  actual_productivity
# count         1197.000000    1197.000000          1197.000000
# mean             0.150376      34.609858             0.735091
# std              0.427848      22.197687             0.174488
# min              0.000000       2.000000             0.233705
# 25%              0.000000       9.000000             0.650307
# 50%              0.000000      34.000000             0.773333
# 75%              0.000000      57.000000             0.850253
# max              2.000000      89.000000             1.120437

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Checking For Null Values**

# %%
#checking for null values
data.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
#imporing data analysis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
plt.figure(figsize=(8,8))
sns.distplot(data.wip)
plt.show()
# Out:
# <ipython-input-544-296dc103163d>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.wip)

# %%
#replace the null values with mean
data['wip'].fillna(data['wip'].mean(),inplace=True)

# %%
#checking for null values
data.isnull().sum()
# Out:
# date                     0
# quarter                  0
# department               0
# day                      0
# team                     0
# targeted_productivity    0
# smv                      0
# wip                      0
# over_time                0
# incentive                0
# idle_time                0
# idle_men                 0
# no_of_style_change       0
# no_of_workers            0
# actual_productivity      0
# dtype: int64

# %% [markdown]
# ### **Handling Data And Department Column**

# %%
#printing first 5 rows
data.head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv          wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.000000       7080         98        0.0         0
# 1   3.94  1190.465991        960          0        0.0         0
# 2  11.41   968.000000       3660         50        0.0         0
# 3  11.41   968.000000       3660         50        0.0         0
# 4  25.90  1170.000000       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 1                   0            8.0             0.886500
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382

# %%
#handling date and department column
data['date']=pd.to_datetime(data['date'])

# %%
data['month'] = data['date'].dt.month
data.drop('date', axis=1, inplace=True)

# %%
data.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1192    3
# 1193    3
# 1194    3
# 1195    3
# 1196    3
# Name: month, Length: 1197, dtype: int32

# %%
data['department'].value_counts()
# Out:
# department
# sweing        691
# finishing     257
# finishing     249
# Name: count, dtype: int64

# %%
data['department']=data['department'].apply(lambda x:'finishing' if x.replace(" ","")=='finishing' else 'sweing')
data['department'].value_counts()
# Out:
# department
# sweing       691
# finishing    506
# Name: count, dtype: int64

# %% [markdown]
# ### **Handling Categorical Values**

# %%
data.head()
# Out:
#     quarter department       day  team  targeted_productivity    smv  \
# 0  Quarter1     sweing  Thursday     8                   0.80  26.16
# 1  Quarter1  finishing  Thursday     1                   0.75   3.94
# 2  Quarter1     sweing  Thursday    11                   0.80  11.41
# 3  Quarter1     sweing  Thursday    12                   0.80  11.41
# 4  Quarter1     sweing  Thursday     6                   0.80  25.90
#
#            wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  1108.000000       7080         98        0.0         0                   0
# 1  1190.465991        960          0        0.0         0                   0
# 2   968.000000       3660         50        0.0         0                   0
# 3   968.000000       3660         50        0.0         0                   0
# 4  1170.000000       1920         50        0.0         0                   0
#
#    no_of_workers  actual_productivity  month
# 0           59.0             0.940725      1
# 1            8.0             0.886500      1
# 2           30.5             0.800570      1
# 3           30.5             0.800570      1
# 4           56.0             0.800382      1

# %%
data['quarter'].value_counts()
# Out:
# quarter
# Quarter1    360
# Quarter2    335
# Quarter4    248
# Quarter3    210
# Quarter5     44
# Name: count, dtype: int64

# %%
data['department'].value_counts()
# Out:
# department
# sweing       691
# finishing    506
# Name: count, dtype: int64

# %%
data['day'].value_counts()
# Out:
# day
# Wednesday    208
# Sunday       203
# Tuesday      201
# Thursday     199
# Monday       199
# Saturday     187
# Name: count, dtype: int64

# %%
#encoding the categorical values
#importing label encoder
from sklearn.preprocessing import LabelEncoder

# %%
Encoder=LabelEncoder()

# %%
data['quarter']=Encoder.fit_transform(data['quarter'])
data['department']=Encoder.fit_transform(data['department'])
data['day']=Encoder.fit_transform(data['day'])

# %%
#printing first 5 values
data.head()
# Out:
#    quarter  department  day  team  targeted_productivity    smv          wip  \
# 0        0           1    3     8                   0.80  26.16  1108.000000
# 1        0           0    3     1                   0.75   3.94  1190.465991
# 2        0           1    3    11                   0.80  11.41   968.000000
# 3        0           1    3    12                   0.80  11.41   968.000000
# 4        0           1    3     6                   0.80  25.90  1170.000000
#
#    over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0       7080         98        0.0         0                   0
# 1        960          0        0.0         0                   0
# 2       3660         50        0.0         0                   0
# 3       3660         50        0.0         0                   0
# 4       1920         50        0.0         0                   0
#
#    no_of_workers  actual_productivity  month
# 0           59.0             0.940725      1
# 1            8.0             0.886500      1
# 2           30.5             0.800570      1
# 3           30.5             0.800570      1
# 4           56.0             0.800382      1

# %% [markdown]
# ### **Correlation Analysis**

# %%
data.corr()
# Out:
#                         quarter    department       day      team  \
# quarter                1.000000 -1.244082e-02 -0.024301  0.021038
# department            -0.012441  1.000000e+00  0.005470  0.031753
# day                   -0.024301  5.469741e-03  1.000000 -0.011434
# team                   0.021038  3.175305e-02 -0.011434  1.000000
# targeted_productivity -0.112319 -6.750822e-02 -0.017908  0.030274
# smv                   -0.000105  8.742295e-01  0.007971 -0.110011
# wip                   -0.064686 -1.799716e-17 -0.122116 -0.025384
# over_time              0.026654  6.775190e-01 -0.018269 -0.096737
# incentive             -0.028237  4.578186e-02 -0.114016 -0.007674
# idle_time             -0.060779  4.918105e-02 -0.008913  0.003796
# idle_men              -0.023884  9.670136e-02  0.029340  0.026974
# no_of_style_change     0.189905  3.008893e-01  0.025941 -0.011194
# no_of_workers         -0.005594  9.393596e-01  0.008078 -0.075113
# actual_productivity   -0.051970 -8.762407e-02 -0.015690 -0.148753
# month                 -0.333715 -3.405626e-03  0.055962  0.000609
#
#                        targeted_productivity       smv           wip  \
# quarter                            -0.112319 -0.000105 -6.468595e-02
# department                         -0.067508  0.874230 -1.799716e-17
# day                                -0.017908  0.007971 -1.221165e-01
# team                                0.030274 -0.110011 -2.538413e-02
# targeted_productivity               1.000000 -0.069489  4.911436e-02
# smv                                -0.069489  1.000000 -1.832200e-02
# wip                                 0.049114 -0.018322  1.000000e+00
# over_time                          -0.088557  0.674887  1.448984e-02
# incentive                           0.032768  0.032629  2.188073e-02
# idle_time                          -0.056181  0.056863 -2.626750e-02
# idle_men                           -0.053818  0.105901 -4.848957e-02
# no_of_style_change                 -0.209294  0.315388 -6.900387e-02
# no_of_workers                      -0.084288  0.912176  9.790782e-03
# actual_productivity                 0.421594 -0.122089  8.836461e-02
# month                              -0.048426 -0.001459  6.853386e-03
#
#                        over_time  incentive  idle_time  idle_men  \
# quarter                 0.026654  -0.028237  -0.060779 -0.023884
# department              0.677519   0.045782   0.049181  0.096701
# day                    -0.018269  -0.114016  -0.008913  0.029340
# team                   -0.096737  -0.007674   0.003796  0.026974
# targeted_productivity  -0.088557   0.032768  -0.056181 -0.053818
# smv                     0.674887   0.032629   0.056863  0.105901
# wip                     0.014490   0.021881  -0.026267 -0.048490
# over_time               1.000000  -0.004793   0.031038 -0.017913
# incentive              -0.004793   1.000000  -0.012024 -0.021140
# idle_time               0.031038  -0.012024   1.000000  0.559146
# idle_men               -0.017913  -0.021140   0.559146  1.000000
# no_of_style_change      0.059790  -0.026607  -0.011598  0.133632
# no_of_workers           0.734164   0.049222   0.058049  0.106946
# actual_productivity    -0.054206   0.076538  -0.080851 -0.181734
# month                  -0.244066   0.118412   0.022880  0.077930
#
#                        no_of_style_change  no_of_workers  actual_productivity  \
# quarter                          0.189905      -0.005594            -0.051970
# department                       0.300889       0.939360            -0.087624
# day                              0.025941       0.008078            -0.015690
# team                            -0.011194      -0.075113            -0.148753
# targeted_productivity           -0.209294      -0.084288             0.421594
# smv                              0.315388       0.912176            -0.122089
# wip                             -0.069004       0.009791             0.088365
# over_time                        0.059790       0.734164            -0.054206
# incentive                       -0.026607       0.049222             0.076538
# idle_time                       -0.011598       0.058049            -0.080851
# idle_men                         0.133632       0.106946            -0.181734
# no_of_style_change               1.000000       0.327787            -0.207366
# no_of_workers                    0.327787       1.000000            -0.057991
# actual_productivity             -0.207366      -0.057991             1.000000
# month                            0.211615      -0.011294            -0.092914
#
#                           month
# quarter               -0.333715
# department            -0.003406
# day                    0.055962
# team                   0.000609
# targeted_productivity -0.048426
# smv                   -0.001459
# wip                    0.006853
# over_time             -0.244066
# incentive              0.118412
# idle_time              0.022880
# idle_men               0.077930
# no_of_style_change     0.211615
# no_of_workers         -0.011294
# actual_productivity   -0.092914
# month                  1.000000

# %%
#visualizing correlation using heat maps
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
#Highlighting correlations specifically with target
corr = data.corr()
target_col=corr[['actual_productivity']].sort_values(by='actual_productivity', ascending=False)

plt.figure(figsize=(8,6))

sns.heatmap(target_col,annot=True)
plt.title("Correlations between predictors and target column")
plt.show()

# %% [markdown]
# ### **Splitting Data Into Train And Split**

# %%
#splitting data into features and target column
x = data.drop(columns=['actual_productivity'], axis=1)
y = data['actual_productivity']

# %%
print(x)
# Out:
#       quarter  department  day  team  targeted_productivity    smv  \
# 0           0           1    3     8                   0.80  26.16
# 1           0           0    3     1                   0.75   3.94
# 2           0           1    3    11                   0.80  11.41
# 3           0           1    3    12                   0.80  11.41
# 4           0           1    3     6                   0.80  25.90
# ...       ...         ...  ...   ...                    ...    ...
# 1192        1           0    5    10                   0.75   2.90
# 1193        1           0    5     8                   0.70   3.90
# 1194        1           0    5     7                   0.65   3.90
# 1195        1           0    5     9                   0.75   2.90
# 1196        1           0    5     6                   0.70   2.90
#
#               wip  over_time  incentive  idle_time  idle_men  \
# 0     1108.000000       7080         98        0.0         0
# 1     1190.465991        960          0        0.0         0
# 2      968.000000       3660         50        0.0         0
# 3      968.000000       3660         50        0.0         0
# 4     1170.000000       1920         50        0.0         0
# ...           ...        ...        ...        ...       ...
# 1192  1190.465991        960          0        0.0         0
# 1193  1190.465991        960          0        0.0         0
# 1194  1190.465991        960          0        0.0         0
# 1195  1190.465991       1800          0        0.0         0
# 1196  1190.465991        720          0        0.0         0
#
#       no_of_style_change  no_of_workers  month
# 0                      0           59.0      1
# 1                      0            8.0      1
# 2                      0           30.5      1
# 3                      0           30.5      1
# 4                      0           56.0      1
# ...                  ...            ...    ...
# 1192                   0            8.0      3
# 1193                   0            8.0      3
# 1194                   0            8.0      3
# 1195                   0           15.0      3
# 1196                   0            6.0      3
#
# [1197 rows x 14 columns]

# %%
print(y)
# Out:
# 0       0.940725
# 1       0.886500
# 2       0.800570
# 3       0.800570
# 4       0.800382
#           ...
# 1192    0.628333
# 1193    0.625625
# 1194    0.625625
# 1195    0.505889
# 1196    0.394722
# Name: actual_productivity, Length: 1197, dtype: float64

# %%
#splitting data into train test split
#import train_test_split dependency
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((1197, 14), (957, 14), (240, 14))

# %% [markdown]
# # **Scaling**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

x_train_scaled=x_train
x_test_scaled=x_test

# %% [markdown]
# # **Model Building**

# %%
#importing the metrics libraries
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### **Linear Regression Model**

# %%
#model building
#importing linear regression dependency
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_train,y_train)
#linear model mean squared error
score_train=linear.predict(x_train)
mse_train=mean_squared_error(y_train,score_train)
print("mean squared error in training data in linear regression is:",mse_train)

score_test=linear.predict(x_test)
mse_test=mean_squared_error(y_test,score_test)
print("mean squared error in testing data in linear regression is:",mse_test)

#linear model r2_score
score_train=linear.predict(x_train)
mse_train=r2_score(y_train,score_train)
print("r2_score in training data in linear regression is:",mse_train)

score_test=linear.predict(x_test)
mse_test=r2_score(y_test,score_test)
print("r2_score in test data in linear regression is:",mse_test)

#linear model mean_absolute_error
score_train=linear.predict(x_train)
mse_train=mean_absolute_error(y_train,score_train)
print("mean_absolute_error in training data in linear regression is:",mse_train)

score_test=linear.predict(x_test)
mse_test=mean_absolute_error(y_test,score_test)
print("mean_absolute_error in testing data in linear regression is:",mse_test)
# Out:
# mean squared error in training data in linear regression is: 0.021829740434257082
# mean squared error in testing data in linear regression is: 0.021321517772632737
# r2_score in training data in linear regression is: 0.3038198342280549
# r2_score in test data in linear regression is: 0.1970042499190925
# mean_absolute_error in training data in linear regression is: 0.10769706277175743
# mean_absolute_error in testing data in linear regression is: 0.10729554202727433

# %% [markdown]
# ### **Random Forest Model**

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
RandomForest = RandomForestRegressor()
RandomForest.fit(x_train, y_train)

#Random Forest Regressor mean squared error
score_train=RandomForest.predict(x_train)
mse_train=mean_squared_error(y_train,score_train)
print("mean squared error in training data in Random Forest Regressor is:",mse_train)

score_test=RandomForest.predict(x_test)
mse_test=mean_squared_error(y_test,score_test)
print("mean squared error in testing data in Random Forest Regressor is:",mse_test)

#Random Forest Regressor r2_score
score_train=RandomForest.predict(x_train)
mse_train=r2_score(y_train,score_train)
print("r2_score in training data in Random Forest Regressor is:",mse_train)

score_test=RandomForest.predict(x_test)
mse_test=r2_score(y_test,score_test)
print("r2_score in test data in Random Forest Regressor is:",mse_test)

#Random Forest Regressor mean_absolute_error
score_train=linear.predict(x_train)
mse_train=mean_absolute_error(y_train,score_train)
print("mean_absolute_error in training data in Random Forest Regressor is:",mse_train)

score_test=linear.predict(x_test)
mse_test=mean_absolute_error(y_test,score_test)
print("mean_absolute_error in testing data in Random Forest Regressor is:",mse_test)
# Out:
# mean squared error in training data in Random Forest Regressor is: 0.0022752182381708293
# mean squared error in testing data in Random Forest Regressor is: 0.011925308844873023
# r2_score in training data in Random Forest Regressor is: 0.9274401903683915
# r2_score in test data in Random Forest Regressor is: 0.5508775490117057
# mean_absolute_error in training data in Random Forest Regressor is: 0.10769706277175743
# mean_absolute_error in testing data in Random Forest Regressor is: 0.10729554202727433

# %% [markdown]
# ### **Xgboost Model**

# %%
#Xgboost regression
import xgboost as xgb
model_xgb=xgb.XGBRegressor(n_estimators=200,max_depth=5,learning_rate=0.1)
model_xgb.fit(x_train,y_train)


#Xgboost mean squared error
score_train=model_xgb.predict(x_train)
mse_train=mean_squared_error(y_train,score_train)
print("mean squared error in training data in Xgboost regression is:",mse_train)

score_test=model_xgb.predict(x_test)
mse_test=mean_squared_error(y_test,score_test)
print("mean squared error in testing data in Xgboost regressionr is:",mse_test)

#Xgboost Regressor r2_score
score_train=model_xgb.predict(x_train)
mse_train=r2_score(y_train,score_train)
print("r2_score in training data in Xgboost regression is:",mse_train)

score_test=model_xgb.predict(x_test)
mse_test=r2_score(y_test,score_test)
print("r2_score in test data in Random Xgboost regressionr is:",mse_test)

#Xgboost regression mean_absolute_error
score_train=linear.predict(x_train)
mse_train=mean_absolute_error(y_train,score_train)
print("mean_absolute_error in training data in Xgboost regression is:",mse_train)

score_test=linear.predict(x_test)
mse_test=mean_absolute_error(y_test,score_test)
print("mean_absolute_error in testing data in Xgboost regression is:",mse_test)
# Out:
# mean squared error in training data in Xgboost regression is: 0.0036951760704128597
# mean squared error in testing data in Xgboost regressionr is: 0.012631486322544742
# r2_score in training data in Xgboost regression is: 0.8821558003859931
# r2_score in test data in Random Xgboost regressionr is: 0.5242819980091831
# mean_absolute_error in training data in Xgboost regression is: 0.10769706277175743
# mean_absolute_error in testing data in Xgboost regression is: 0.10729554202727433

# %% [markdown]
# ### **Compare The Model**

# %% [markdown]
# Based on the provided metrics for the three models (Linear Regression, Random Forest Regressor, and XGBoost Regressor), we can make the following observations:
#
# 1)Linear Regression:
# Moderate Mean Squared Error (MSE) values for both training and testing data.
# Relatively low R-squared (R2) scores, indicating weaker fit to the data.
# Consistent Mean Absolute Error (MAE) values.
#
# 2)Random Forest Regressor:
# Lowest Mean Squared Error (MSE) on testing data among the three models, indicating better prediction accuracy.
# High R-squared (R2) scores on both training and testing data, suggesting a good fit to the data and capturing more variance.
# Consistent Mean Absolute Error (MAE) values.
#
# 3)XGBoost Regressor:
# Moderate Mean Squared Error (MSE) values on both training and testing data.
# Lower R-squared (R2) scores compared to Random Forest Regressor, indicating slightly weaker performance in capturing variance.
# Consistent Mean Absolute Error (MAE) values.
#
# Conclusion:
# Based on the provided metrics, the Random Forest Regressor appears to be the best-performing model. It demonstrates the lowest Mean Squared Error (MSE) on the testing data, indicating superior prediction accuracy. Additionally, it exhibits high R-squared (R2) scores on both training and testing data, suggesting a robust fit to the data and capturing more variance compared to the other models. Therefore, for this specific task, the Random Forest Regressor is recommended for further exploration and deployment.

# %% [markdown]
# ### **Evaluating Performance Of The Model And Saving The Model**

# %%
#evaluating and saving the final model
final_model=RandomForestRegressor()
final_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#Random Forest Regressor mean squared error(final model)
score_train=RandomForest.predict(x_train)
mse_train=mean_squared_error(y_train,score_train)
print("mean squared error in training data in Random Forest Regressor is:",mse_train)

score_test=RandomForest.predict(x_test)
mse_test=mean_squared_error(y_test,score_test)
print("mean squared error in testing data in Random Forest Regressor is:",mse_test)
# Out:
# mean squared error in training data in Random Forest Regressor is: 0.0022421391420198965
# mean squared error in testing data in Random Forest Regressor is: 0.011857027221930112

# %%
#Random Forest Regressor r2_score(final model)
score_train=RandomForest.predict(x_train)
mse_train=r2_score(y_train,score_train)
print("r2_score in training data in Random Forest Regressor is:",mse_train)

score_test=RandomForest.predict(x_test)
mse_test=r2_score(y_test,score_test)
print("r2_score in test data in Random Forest Regressor is:",mse_test)
# Out:
# r2_score in training data in Random Forest Regressor is: 0.9284951278153711
# r2_score in test data in Random Forest Regressor is: 0.5534491226499652

# %%
#Random Forest Regressor mean_absolute_error(final model)
score_train=linear.predict(x_train)
mse_train=mean_absolute_error(y_train,score_train)
print("mean_absolute_error in training data in Random Forest Regressor is:",mse_train)

score_test=linear.predict(x_test)
mse_test=mean_absolute_error(y_test,score_test)
print("mean_absolute_error in testing data in Random Forest Regressor is:",mse_test)
# Out:
# mean_absolute_error in training data in Random Forest Regressor is: 0.10769706277175743
# mean_absolute_error in testing data in Random Forest Regressor is: 0.10729554202727433

# %%
#making a predictive system
data = [0,1,3,8,0.80,26.16,1108.000000,7080,98,0.0,0,0,59.0,1]
data = np.array(data).reshape(1, -1)  # Reshape data into a 2D array
prediction = final_model.predict(data)
print(prediction)
# Out:
# [0.94034122]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
predicted_values=final_model.predict(x_test)
print(predicted_values)
# Out:
# [0.43285815 0.79939752 0.67112102 0.59102757 0.59363826 0.73593106
#  0.54965459 0.52631061 0.63104665 0.75039129 0.69169065 0.93796835
#  0.8036123  0.73975661 0.87060363 0.92217939 1.00768066 0.59663111
#  0.57932836 0.90422403 1.00967053 0.69873054 0.89310746 0.90322025
#  0.82536929 0.51401166 0.76043825 0.99930291 0.48291914 0.87801266
#  0.9304564  0.80130305 0.7887188  0.84647422 0.70221317 0.44679818
#  0.86767301 0.78928101 0.80039574 0.67061375 0.79290228 0.85549883
#  0.64355713 0.92648641 0.75063595 0.79988945 0.5378957  0.89826874
#  0.77992212 0.84255738 0.76737274 0.82130754 0.63688191 0.81218191
#  0.39974405 0.65304169 0.47854269 0.75205543 0.90415766 0.73700941
#  0.62518144 0.67531454 0.54025252 0.82110302 0.4523998  0.76521943
#  0.80521619 0.7736817  0.49447118 0.63739389 0.80345766 0.62076708
#  0.70031311 0.73235079 0.75484291 0.56726455 0.76918528 0.69442126
#  0.83137592 0.82374413 0.78618602 0.83004841 0.85765716 0.74155823
#  0.73173633 0.70162266 0.67800335 0.82374362 0.97995332 0.53040903
#  0.52996175 0.75573899 0.80664286 0.69507621 0.80319347 0.74694186
#  0.70258992 0.81912756 0.7206753  0.78539105 0.79585155 0.80184015
#  0.99840335 0.69200764 0.7016168  0.75510418 0.70033712 0.7192606
#  0.75061228 0.77974948 0.81334596 0.84752224 0.67784972 0.86387578
#  0.65667094 0.73296603 0.85652609 0.79910834 0.68791865 0.47855742
#  0.46260628 0.82712341 0.66759556 0.58888661 0.75090267 0.74803064
#  0.89775691 0.8986253  0.79938624 0.80151498 0.68771283 0.65536
#  0.63512411 0.70969525 0.48025428 0.85115312 0.42735861 0.77807576
#  0.50751756 0.79249724 0.76412535 0.84249377 0.77611461 0.68677017
#  0.69290203 0.79791847 0.41292763 0.8799311  0.4437786  0.49233129
#  0.82483076 0.65837358 0.81073137 0.59975765 0.69219253 0.73654486
#  0.73765    0.79220482 0.94033609 0.81593256 0.54736197 0.6096642
#  0.75063668 0.58381112 0.55745587 0.68853688 0.81250687 0.69481
#  0.7163457  0.80012095 0.54281044 0.65545447 0.86413941 0.62495613
#  0.85133203 0.80213505 0.67818005 0.58460998 0.85201005 0.77793276
#  0.79046516 0.8999051  0.68079473 0.67918883 0.77877989 0.66337193
#  0.53557167 0.81779871 0.83948132 0.63660534 0.68609508 0.61960898
#  0.69450506 0.85342973 0.84354015 0.85225137 0.60251051 1.0012814
#  0.66933948 0.54436761 0.68749134 0.86396989 0.41083213 0.82804953
#  0.3601485  0.83155577 0.85688196 0.46249364 0.8003954  0.73756542
#  0.6945159  0.75139585 0.77090423 0.70727696 0.7343906  0.83952677
#  0.70827114 0.81836806 0.91322613 0.78629838 0.75521058 0.87518203
#  0.74280441 0.64870216 0.77742055 0.8402147  0.88829302 0.86819158
#  0.68898845 1.00269102 0.4502814  0.82373977 0.76147841 0.8155643
#  0.66083286 0.65345417 0.87195784 0.58521333 0.82901691 0.80760222]

# %%
Purchased = pd.DataFrame({'Actual Value':y_test,'predicted_value':predicted_values})
Purchased.head(20)
# Out:
#       Actual Value  predicted_value
# 921       0.268214         0.432858
# 321       0.800359         0.799398
# 101       0.681061         0.671121
# 920       0.325000         0.591028
# 58        0.667604         0.593638
# 790       0.800980         0.735931
# 948       0.768847         0.549655
# 969       0.768847         0.526311
# 410       0.650417         0.631047
# 1079      0.750396         0.750391
# 572       0.700398         0.691691
# 44        0.861679         0.937968
# 49        0.800319         0.803612
# 844       0.816406         0.739757
# 240       0.900145         0.870604
# 170       0.935322         0.922179
# 732       1.000345         1.007681
# 761       0.600448         0.596631
# 723       0.714410         0.579328
# 422       0.900321         0.904224
